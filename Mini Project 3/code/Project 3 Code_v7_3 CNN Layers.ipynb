# %%
# COMP-551 Mini-Project #3.
# Written by Ryan Wilson.
# Encoding = UTF-8.

############################################################################
###################       LIBRARY & MODULE IMPORTS       ###################
############################################################################

# Import numpy, pandas & matplotlib.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Import h5py & pathlib modules.
import h5py
from pathlib import Path

# %%
# Import pytorch & torchvision modules.
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, SGD
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader, Subset

import torchvision
from torchvision.transforms import transforms

# Import preprocessing & classifier modules from scikit-learn.
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
############################################################################
##########       DATA IMPORT/INITIALIZATION & PREPROCESSING       ##########
############################################################################

# Move the model to train on GPU if available (Else: CPU).
device = ("cuda" if torch.cuda.is_available() else "cpu")

file_path = "MNIST_synthetic.h5"

class HDF5Dataset(Dataset):
    def __init__(self, file_path, train, transform=None):
        self.archive = h5py.File(file_path, 'r')
        self.train_data = self.archive['train_dataset']
        self.train_labels = self.archive['train_labels']
        self.test_data = self.archive['test_dataset']
        self.test_labels = np.empty(len(self.test_data))
        self.transform = transform
        self.train = train

    def __getitem__(self, index):
        if self.train is True:
            data = self.train_data[index]
            if self.transform is not None:
                data = self.transform(data)
            return data, self.train_labels[index]

        else:
            data = self.test_data[index]
            if self.transform is not None:
                data = self.transform(data)
            return data

    def __len__(self):
        if self.train is True:
            return len(self.train_labels)
        else:
            return len(self.test_labels)

    def close(self):
        self.archive.close()

def train_val_dataset(dataset, val_split=0.2):
    train_idx, val_idx = train_test_split(list(range(len(dataset))), \
        test_size=val_split, shuffle=True, random_state=21)
    train_val_splits = {}
    train_val_splits['train'] = Subset(dataset, train_idx)
    train_val_splits['val'] = Subset(dataset, val_idx)
    return train_val_splits

def test_dataset(dataset):
    test_idx = list(range(len(dataset)))
    test_split = {}
    test_split['test'] = Subset(dataset, test_idx)
    return test_split

# Create transform function to pass into HDF5Dataset class.
transform = transforms.Compose([transforms.ToTensor(), \
    transforms.Normalize((0.5), (0.5))])

# Test HDF5 class definition & print train/test dataset sizes.
dataset = HDF5Dataset(file_path, train=True, transform=transform)
print(dataset.train_data)
print(dataset.train_labels)
print(dataset.test_data)
print()

# Print the length of the entire passed dataset.
print("Dataset Length:", len(dataset))
print()

# Split into train/validation sets & print respective lengths.
train_val_splits = train_val_dataset(dataset)
print("Train Set Length:", len(train_val_splits['train']))
print("Val Set Length:", len(train_val_splits['val']))
print()

# Pass train/validation splits into PyTorch DataLoader function.
def cycle(iterable):
    while True:
        for x in iterable:
            yield x

train_loader = DataLoader(train_val_splits['train'], batch_size=64, shuffle=True, num_workers=0, pin_memory=True)
train_iter = iter(cycle(train_loader))

val_loader = DataLoader(train_val_splits['val'], batch_size=64, shuffle=True, num_workers=0, pin_memory=True)
val_iter = iter(cycle(val_loader))

# Define image plotting function.
def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Acquire random training images.
dataiter = iter(train_loader)
images, labels = dataiter.next()

# Plot test images to ensure proper functionality.
imshow(torchvision.utils.make_grid(images))
# Out:
# <HDF5 dataset "train_dataset": shape (56000, 64, 64, 1), type "|u1">
# <HDF5 dataset "train_labels": shape (56000, 5), type "<i4">
# <HDF5 dataset "test_dataset": shape (14000, 64, 64, 1), type "|u1">
#
# Dataset Length: 56000
#
# Train Set Length: 44800
# Val Set Length: 11200

# %%
############################################################################
##############       CONV NEURAL NET (CNN) ARCHITECTURE       ##############
############################################################################

# Define the CNN class architecture.
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.cnn_layers = nn.Sequential(
            # Define convolution layers.
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            #nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.5),

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.2),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(0.2))
        
        self.FC_layer = nn.Sequential(
            # Define fully connected layer.
            nn.Linear(128*16*16, 256),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(256))

        self.digitlength = nn.Sequential(nn.Linear(256, 7))
        self.digit1 = nn.Sequential(nn.Linear(256, 11))
        self.digit2 = nn.Sequential(nn.Linear(256, 11))
        self.digit3 = nn.Sequential(nn.Linear(256, 11))
        self.digit4 = nn.Sequential(nn.Linear(256, 11))
        self.digit5 = nn.Sequential(nn.Linear(256, 11))

    # Define the forward pass mechanism.
    def forward(self, X):
        X = self.cnn_layers(X)
        X = X.view(-1, 128*16*16)
        X = self.FC_layer(X)

        len_digit = self.digitlength(X)
        y1 = self.digit1(X)
        y2 = self.digit2(X)
        y3 = self.digit3(X)
        y4 = self.digit4(X)
        y5 = self.digit5(X)
        return X, [len_digit, y1, y2, y3, y4, y5]

# Call the model & define the optimizer/loss function.
model = CNN()
optimizer = Adam(model.parameters(), lr=0.005)
"""optimizer = SGD(model.parameters(), lr=0.005, momentum=0.9, weight_decay=0.0005)"""
loss_fn = nn.CrossEntropyLoss()

# Pass the model to GPU (if available).
if torch.cuda.is_available():
    model = model.cuda()
    loss_fn = loss_fn.cuda()

# Print the model (parameters).
print(model)
print()
# Out:
# CNN(
#   (cnn_layers): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (13): Dropout(p=0.2, inplace=False)
#   )
#   (FC_layer): Sequential(
#     (0): Linear(in_features=32768, out_features=256, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (digitlength): Sequential(
#     (0): Linear(in_features=256, out_features=7, bias=True)
#   )
#   (digit1): Sequential(
#     (0): Linear(in_features=256, out_features=11, bias=True)
#   )
#   (digit2): Sequential(
#     (0): Linear(in_features=256, out_features=11, bias=True)
#   )
#   (digit3): Sequential(
#     (0): Linear(in_features=256, out_features=11, bias=True)
#   )
#   (digit4): Sequential(
#     (0): Linear(in_features=256, out_features=11, bias=True)
#   )
#   (digit5): Sequential(
#     (0): Linear(in_features=256, out_features=11, bias=True)
#   )
# )

# %%
############################################################################
###########       CNN TRAINING MODEL (FUNCTION DEFINITION)       ###########
############################################################################

# Initialize empty lists for train & val loss histories.
train_loss_epoch = []
val_loss_epoch = []

train_loss_history = []
val_loss_history = []

# Define a CNN training model function.
def train(epoch):
    model.train()
    training_loss = 0

    for i, data in enumerate(train_loader):
        # Acquire the training set.
        X_train, y_train = next(train_iter)
        y_train = y_train.long()

        train_X, train_y = Variable(X_train), Variable(y_train)

        # Convert the data into GPU format (if available).
        if torch.cuda.is_available():
            train_X = train_X.cuda()
            train_y = train_y.cuda()

        # Clear the gradients of the model parameters.
        optimizer.zero_grad()
    
        # Make predictions for training set.
        yhat_train = model(train_X)

        # Compute & append the training losses.
        train_loss1 = loss_fn(yhat_train[1][1], train_y[:, 0])
        train_loss2 = loss_fn(yhat_train[1][2], train_y[:, 1])
        train_loss3 = loss_fn(yhat_train[1][3], train_y[:, 2])
        train_loss4 = loss_fn(yhat_train[1][4], train_y[:, 3])
        train_loss5 = loss_fn(yhat_train[1][5], train_y[:, 4])
        train_loss = train_loss1 + train_loss2 + train_loss3 + train_loss4 + train_loss5
        train_loss.backward()

        train_loss_epoch.append(train_loss)
        train_loss_history.append(train_loss)

        # Compute updated weights for the model parameters.
        optimizer.step()
        training_loss = train_loss.item()

        # Print the training loss.
        if epoch%1 == 0:
            print('Epoch: ', epoch+1, '\t', 'train loss:', train_loss)

def validate(epoch):
    model.train()
    validation_loss = 0

    for i, data in enumerate(val_loader):
        # Acquire the validation set.
        X_val, y_val = next(val_iter)
        y_val = y_val.long()

        val_X, val_y = Variable(X_val), Variable(y_val)

        # Convert the data into GPU format (if available).
        if torch.cuda.is_available():
            val_X = val_X.cuda()
            val_y = val_y.cuda()

        # Clear the gradients of the model parameters.
        optimizer.zero_grad()

        # Make predictions for validation set.
        yhat_val = model(val_X)

        # Compute & append the validation losses.
        val_loss1 = loss_fn(yhat_val[1][1], val_y[:, 0])
        val_loss2 = loss_fn(yhat_val[1][2], val_y[:, 1])
        val_loss3 = loss_fn(yhat_val[1][3], val_y[:, 2])
        val_loss4 = loss_fn(yhat_val[1][4], val_y[:, 3])
        val_loss5 = loss_fn(yhat_val[1][5], val_y[:, 4])
        val_loss = val_loss1 + val_loss2 + val_loss3 + val_loss4 + val_loss5
        val_loss.backward()

        val_loss_epoch.append(val_loss)
        val_loss_history.append(val_loss)

        # Compute updated weights for the model parameters.
        optimizer.step()

        # Print the validation loss.
        if epoch%1 == 0:
            print('Epoch: ', epoch+1, '\t', 'val loss:', val_loss)

# User to define the number of training epochs.
n_epochs = 25

# Initiate CNN model training & validation.
for epoch in range(n_epochs):
    train(epoch)
    validate(epoch)
    print()

    """# Plot the training & validation loss histories.
    plt.plot(train_loss_epoch, label='Training Loss')
    plt.plot(val_loss_epoch, label='Validation Loss')
    plt.title('Training/Validation Loss History')
    plt.xlabel(f"Epoch {epoch+1}")
    plt.ylabel('Cross Entropy Loss')
    plt.legend()
    plt.show()

    train_loss_epoch.clear()
    val_loss_epoch.clear()"""

# Plot the training & validation loss histories.
plt.plot(train_loss_history, label='Training Loss')
plt.plot(val_loss_history, label='Validation Loss')
plt.title('Training/Validation Loss History')
plt.xlabel('Epochs')
plt.ylabel('Cross Entropy Loss')
plt.legend()
plt.show()
# Out:
# Epoch:  1 	 train loss: tensor(12.7163, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(9.9743, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(9.2818, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(8.8820, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(8.5341, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(8.6458, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(8.0864, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.9942, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.2424, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.5734, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.4643, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.0943, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.7544, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.4388, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.2896, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.7099, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.9976, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.1914, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.8751, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.1795, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.7637, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.3243, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.3819, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.4662, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.2736, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.9170, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.7667, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.7681, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.0582, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.7318, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.4603, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.8427, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.7379, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.7044, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.4208, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.1313, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.3829, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.2160, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.2103, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.0718, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(7.1933, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.7663, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.7765, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.9213, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.3384, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.9556, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.2933, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.5158, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.8684, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.2112, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.6836, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.8736, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.4931, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.0808, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.8646, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.6175, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.3221, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.6872, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.6319, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.7249, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.1295, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.9663, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.6758, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.6828, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.8370, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.2357, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.2000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(6.2183, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.6851, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.5551, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.6614, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.3656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.4905, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.3503, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.4459, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.8090, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.4844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.3590, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.0559, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.2837, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.8636, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.1232, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.7759, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.9046, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.1354, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.5664, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.8647, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.9160, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.7734, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.1216, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.3942, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.0078, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.6387, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.0555, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.4381, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.4795, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.5313, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(5.5045, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.4316, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.4936, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.6294, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.2706, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.6386, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.9098, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.8555, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.2586, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.3961, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.6849, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.6988, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.4885, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.3093, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.4239, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.0003, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.1041, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.3264, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.4761, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.4384, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.3115, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.8266, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.0305, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.0538, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.0491, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.9892, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.6622, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.8283, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.9974, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.5271, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.7337, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.1282, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.0553, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.0888, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.9826, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.8415, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.8298, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.2110, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.0243, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.5978, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.1089, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3971, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.0933, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.8782, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.1144, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.9447, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.1701, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3904, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.2170, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(4.0682, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.8815, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.6209, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.5172, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.4035, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.4899, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3503, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3618, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.4130, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3162, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3301, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.1033, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.2366, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3763, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.1971, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.6702, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.6612, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.7009, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3904, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.1981, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.6043, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.0527, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.2108, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.7139, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9036, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.4308, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9077, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.7432, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.3087, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.2034, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9166, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9765, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.2512, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4645, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.6032, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5029, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.3454, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.7177, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9689, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9367, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.8365, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.2636, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9707, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.0139, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.1306, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.1785, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.4034, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.7207, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.8874, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.0221, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1331, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(3.1529, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5866, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.8885, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5320, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.8986, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.6639, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5831, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5680, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9829, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.3090, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5400, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4507, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2541, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.7123, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5560, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.6219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9252, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0908, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1168, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5024, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4536, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.9228, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2914, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2766, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5848, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2127, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1816, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.8123, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2168, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1060, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9150, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.3216, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1928, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4605, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4055, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5181, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1835, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.3346, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4163, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0038, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4669, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8403, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1718, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0882, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1203, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9698, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.3830, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2749, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0090, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.7664, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1440, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2025, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.3805, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.3994, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1521, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7177, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4433, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0116, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2465, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0349, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4936, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7846, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6022, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1630, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.4928, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0623, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.6166, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1829, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7453, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7429, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7039, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5416, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9582, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8949, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0960, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.3192, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2972, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9390, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6430, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0725, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8419, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4890, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0689, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0658, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6726, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6532, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2013, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9171, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7590, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9563, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7115, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4181, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9170, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5200, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5328, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8228, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9423, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6004, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8602, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4266, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6009, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6449, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0487, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3972, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6586, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4545, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4922, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8729, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3833, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3079, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9697, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8174, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5650, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5823, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1450, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0593, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9858, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1890, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.5895, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.2453, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1731, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6913, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8024, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1810, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9815, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8218, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8460, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7069, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9061, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.9664, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0951, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8043, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5565, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7746, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8652, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.1325, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4551, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0827, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7277, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4836, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7666, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8702, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7762, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3749, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(2.0837, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5641, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4496, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5006, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7574, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7030, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1712, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5685, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6354, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1067, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2516, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8044, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2645, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3534, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6675, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2702, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6886, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6217, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7394, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3012, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3247, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5593, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2378, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6824, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2943, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2643, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3884, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5216, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5063, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.6245, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.8372, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1900, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4506, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5059, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3928, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3643, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3254, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1900, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3823, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5443, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0910, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4195, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0113, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5887, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3752, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3934, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3556, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1672, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1803, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5945, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1228, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4374, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0586, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3573, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3575, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0189, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.7963, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1830, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4613, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4898, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4636, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2825, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0983, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0461, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4285, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3345, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3078, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4016, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0814, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9984, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0111, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1463, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0522, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1294, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3749, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2907, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0904, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8772, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3131, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4137, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0887, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1694, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2490, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9597, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1398, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0990, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1355, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1947, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8951, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1489, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2485, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0942, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3186, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0783, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0402, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0143, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2638, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2260, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7746, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4911, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8437, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2476, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9985, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1983, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0163, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1028, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1513, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.5735, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0815, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9574, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1728, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1036, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3208, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8619, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0088, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2726, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8616, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0777, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1975, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8684, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1484, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1215, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1362, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7448, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1091, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0316, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8904, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9799, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7110, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2224, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0021, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1163, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9632, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9949, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9585, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1606, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2899, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2449, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6975, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6845, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0472, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1476, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9099, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9968, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7997, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8830, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9251, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1141, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1283, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2042, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7829, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.5302, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0944, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2655, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9852, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9254, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2006, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8347, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8134, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.3279, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0228, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8154, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0126, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0622, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9184, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0308, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0980, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8645, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0710, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1051, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.4176, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8224, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9058, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8314, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0988, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9915, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1056, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9258, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7211, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8541, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7494, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9922, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2395, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7543, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1083, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6523, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9775, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8222, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1021, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8744, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1174, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8758, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7864, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2849, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6055, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1484, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0707, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9004, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0524, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9409, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8212, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8977, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7042, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2379, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9573, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1715, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7071, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9933, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.1292, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9369, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7763, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0470, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8927, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.9950, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0977, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8490, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2511, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6181, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6448, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0748, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2148, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.2005, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6395, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8473, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.7109, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6422, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8751, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8741, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6736, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8112, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0009, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8390, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.5989, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8040, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6977, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.8672, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0851, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.6168, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(1.0500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  1 	 train loss: tensor(0.5645, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# Epoch:  35 	 train loss: tensor(0.0446, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.1129, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.1675, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0354, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.1284, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0720, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.1508, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0804, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.1002, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0922, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0217, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.1191, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0886, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.1177, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0114, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0958, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0663, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0116, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0086, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.1059, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0636, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.1264, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0264, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 train loss: tensor(0.0512, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0243, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0658, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0674, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1399, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1473, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0149, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0252, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0702, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1504, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0358, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1004, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0865, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0138, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0388, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1299, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1142, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0477, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0141, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0441, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0553, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0203, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0305, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0607, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0834, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0546, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0915, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0387, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0563, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1416, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0478, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0350, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1177, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0124, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0965, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0284, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.2131, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0317, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0484, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0544, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0539, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.3231, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0785, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0395, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0876, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0368, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1130, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0386, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0524, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1836, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1862, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1136, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0979, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0693, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0903, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1622, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0113, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0318, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0322, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0928, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0635, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0240, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0160, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0235, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0256, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1100, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0197, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1569, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0670, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1110, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1356, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0471, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0140, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0432, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0264, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0475, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0545, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1069, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0542, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1184, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0963, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0477, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0633, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0345, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0275, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0147, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1795, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0771, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1233, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0278, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1116, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0362, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0916, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0138, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0368, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0116, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0381, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0341, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1685, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0403, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0149, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0900, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0366, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.4074, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0078, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.2305, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.2321, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0306, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0220, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0596, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0280, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0579, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1001, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0374, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0290, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1535, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0365, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0533, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0995, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0737, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1473, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0861, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0568, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0272, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0359, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0374, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0528, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0974, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1212, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0279, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0867, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0297, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0560, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0590, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0504, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0038, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0956, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1028, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1077, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0466, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0119, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0235, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0138, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1259, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0789, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0856, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0501, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0039, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0662, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0290, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1013, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0543, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0098, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0227, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0166, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.1048, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0090, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0178, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0895, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0389, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0369, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0089, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0297, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0575, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0466, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch:  35 	 val loss: tensor(0.0496, device='cuda:0', grad_fn=<AddBackward0>)

# %%
############################################################################
###############       VALIDATION PREDICTIONS & METRICS       ###############
############################################################################

model.eval()

# Initialize empty lists for final labels & predictions.
y_train_final = []
yhat_train_final = []

# Make predictions for the training set.
for i, data in enumerate(train_loader):
    X_train, y_train = next(train_iter)
    y_train = y_train.long()

    with torch.no_grad():
        output = model(X_train.cuda())

    softmax_train1 = torch.exp(output[1][1]).cpu().numpy()
    softmax_train2 = torch.exp(output[1][2]).cpu().numpy()
    softmax_train3 = torch.exp(output[1][3]).cpu().numpy()
    softmax_train4 = torch.exp(output[1][4]).cpu().numpy()
    softmax_train5 = torch.exp(output[1][5]).cpu().numpy()

    yhat_train1 = np.argmax(softmax_train1, axis=1)
    yhat_train2 = np.argmax(softmax_train2, axis=1)
    yhat_train3 = np.argmax(softmax_train3, axis=1)
    yhat_train4 = np.argmax(softmax_train4, axis=1)
    yhat_train5 = np.argmax(softmax_train5, axis=1)
    yhat_train = np.array([yhat_train1, yhat_train2, yhat_train3, yhat_train4, yhat_train5]).transpose()

    y_train = np.array(y_train)

    y_train_final.append(y_train)
    yhat_train_final.append(yhat_train)

y_train_final = np.vstack(y_train_final)
yhat_train_final = np.vstack(yhat_train_final)

print("Training Labels (y_train_final):")
print(y_train_final)
print()

print("y_train_final shape:", y_train_final.shape)
print()

print("Training Predictions (yhat_train_final):")
print(yhat_train_final)
print()

print("yhat_train_final shape:", yhat_train_final.shape)
print()

yhat_train_final_df = pd.DataFrame(yhat_train_final)
yhat_train_final_df.to_csv('yhat_train_final.csv')

# Compute & print training accuracy.
y_train_final_arr=[]
for i in range(np.shape(y_train_final)[0]):
    r=''.join(map(str, y_train_final[i]))
    y_train_final_arr.append(r)
y_train_final_arr = np.array(y_train_final_arr, dtype=int)

yhat_train_final_arr=[]
for i in range(np.shape(yhat_train_final)[0]):
    r=''.join(map(str, yhat_train_final[i]))
    yhat_train_final_arr.append(r)
yhat_train_final_arr = np.array(yhat_train_final_arr, dtype=int)

total_correct = np.sum(y_train_final_arr == yhat_train_final_arr)
train_accuracy = total_correct / len(yhat_train_final_arr)
print("Training Accuracy:", train_accuracy)
print()

# Compute & print training R2 score.
train_R2_score = r2_score(y_train_final, yhat_train_final)
print("Training R2 Score:", train_R2_score)
print()

# Compute & print training RMSE score.
train_RMSE = np.sqrt(mean_squared_error(y_train_final, yhat_train_final))
print("Training RMSE Score:", train_RMSE)
print()

# Initialize empty lists for final labels & predictions.
y_val_final = []
yhat_val_final = []

# Make predictions for the validation set.
for i, data in enumerate(val_loader):
    X_val, y_val = next(val_iter)
    y_val = y_val.long()

    with torch.no_grad():
        output = model(X_val.cuda())

    softmax_val1 = torch.exp(output[1][1]).cpu().numpy()
    softmax_val2 = torch.exp(output[1][2]).cpu().numpy()
    softmax_val3 = torch.exp(output[1][3]).cpu().numpy()
    softmax_val4 = torch.exp(output[1][4]).cpu().numpy()
    softmax_val5 = torch.exp(output[1][5]).cpu().numpy()

    yhat_val1 = np.argmax(softmax_val1, axis=1)
    yhat_val2 = np.argmax(softmax_val2, axis=1)
    yhat_val3 = np.argmax(softmax_val3, axis=1)
    yhat_val4 = np.argmax(softmax_val4, axis=1)
    yhat_val5 = np.argmax(softmax_val5, axis=1)
    yhat_val = np.array([yhat_val1, yhat_val2, yhat_val3, yhat_val4, yhat_val5]).transpose()

    y_val = np.array(y_val)

    y_val_final.append(y_val)
    yhat_val_final.append(yhat_val)

y_val_final = np.vstack(y_val_final)
yhat_val_final = np.vstack(yhat_val_final)

print("Validation Labels (y_val_final):")
print(y_val_final)
print()

print("y_val_final shape:", y_val_final.shape)
print()

print("Validation Predictions (yhat_val_final):")
print(yhat_val_final)
print()

print("yhat_val_final shape:", yhat_val_final.shape)
print()

yhat_val_final_df = pd.DataFrame(yhat_val_final)
yhat_val_final_df.to_csv('yhat_val_final.csv')

# Compute & print validation accuracy.
y_val_final_arr=[]
for i in range(np.shape(y_val_final)[0]):
    r=''.join(map(str, y_val_final[i]))
    y_val_final_arr.append(r)
y_val_final_arr = np.array(y_val_final_arr, dtype=int)

yhat_val_final_arr=[]
for i in range(np.shape(yhat_val_final)[0]):
    r=''.join(map(str, yhat_val_final[i]))
    yhat_val_final_arr.append(r)
yhat_val_final_arr = np.array(yhat_val_final_arr, dtype=int)

total_correct = np.sum(y_val_final_arr == yhat_val_final_arr)
val_accuracy = total_correct / len(yhat_val_final_arr)
print("Validation Accuracy:", val_accuracy)
print()


# Compute & print validation R2 score.
val_R2_score = r2_score(y_val_final, yhat_val_final)
print("Validation R2 Score:", val_R2_score)
print()

# Compute & print validation RMSE score.
val_RMSE = np.sqrt(mean_squared_error(y_val_final, yhat_val_final))
print("Validation RMSE Score:", val_RMSE)
print()
# Out:
# Training Labels (y_train_final):
# [[ 5  0  5  1  3]
#  [ 1  3  1  3 10]
#  [ 5  6  1 10 10]
#  ...
#  [ 9  4  7  0 10]
#  [ 5  7  1  8 10]
#  [ 5  5 10 10 10]]
#
# y_train_final shape: (44800, 5)
#
# Training Predictions (yhat_train_final):
# [[ 5  0  5  1  3]
#  [ 1  3  1  3 10]
#  [ 1  6  6 10 10]
#  ...
#  [ 9  4  7  0 10]
#  [ 5  7  1  8 10]
#  [ 5  5 10  1 10]]
#
# yhat_train_final shape: (44800, 5)
#
# Training Accuracy: 0.41397321428571426
#
# Training R2 Score: 0.3499259913967935
#
# Training RMSE Score: 2.5554851719948823
#
# Validation Labels (y_val_final):
# [[ 7  0  1  5  6]
#  [ 7  1  8 10 10]
#  [ 0  0  8 10 10]
#  ...
#  [ 7  2  2  2  1]
#  [ 9  3  6 10 10]
#  [ 4  8  2  7  8]]
#
# y_val_final shape: (11200, 5)
#
# Validation Predictions (yhat_val_final):
# [[ 7  0  1  5  6]
#  [ 1  1  1 10 10]
#  [ 1  0  8 10 10]
#  ...
#  [ 7  2  2  2  1]
#  [ 7  3  6 10 10]
#  [ 4  8  2  7  8]]
#
# yhat_val_final shape: (11200, 5)
#
# Validation Accuracy: 0.41401785714285716
#
# Validation R2 Score: 0.32348901491917503
#
# Validation RMSE Score: 2.589318719001473

# %%
############################################################################
##################       TEST PREDICTIONS & METRICS       ##################   
############################################################################

# Test HDF5 class definition & print train/test dataset sizes.
dataset2 = HDF5Dataset(file_path, train=False, transform=transform)
print(dataset2.train_data)
print(dataset2.train_labels)
print(dataset2.test_data)
print()

# Print the length of the entire passed dataset.
print("Dataset Length:", len(dataset2))
print()

# Split into test set & print respective length.
test_split = test_dataset(dataset2)
print("Test Set Length:", len(test_split['test']))
print()

# Pass test split into PyTorch DataLoader function.
test_loader = DataLoader(test_split['test'], batch_size=70, shuffle=False, num_workers=0, pin_memory=True)
test_iter = iter(cycle(test_loader))

# Initialize empty list for final test predictions.
yhat_test_final = []

# Make predictions for the (unseen) test set.
for i, data in enumerate(test_loader):
    X_test = next(test_iter)

    with torch.no_grad():
        output = model(X_test.cuda())

    softmax_test1 = torch.exp(output[1][1]).cpu().numpy()
    softmax_test2 = torch.exp(output[1][2]).cpu().numpy()
    softmax_test3 = torch.exp(output[1][3]).cpu().numpy()
    softmax_test4 = torch.exp(output[1][4]).cpu().numpy()
    softmax_test5 = torch.exp(output[1][5]).cpu().numpy()

    yhat_test1 = np.argmax(softmax_test1, axis=1)
    yhat_test2 = np.argmax(softmax_test2, axis=1)
    yhat_test3 = np.argmax(softmax_test3, axis=1)
    yhat_test4 = np.argmax(softmax_test4, axis=1)
    yhat_test5 = np.argmax(softmax_test5, axis=1)
    yhat_test = np.array([yhat_test1, yhat_test2, yhat_test3, yhat_test4, yhat_test5]).transpose()

    yhat_test_final.append(yhat_test)

yhat_test_final = np.vstack(yhat_test_final)

print("Test Predictions (yhat_test_final):")
print(yhat_test_final)
print()

print("yhat_test_final shape:", yhat_test_final.shape)
print()

yhat_test_final_arr=[]
for i in range(np.shape(yhat_test_final)[0]):
    r=''.join(map(str, yhat_test_final[i]))
    yhat_test_final_arr.append(r)
data_final = {'Id':list(range(np.shape(yhat_test_final)[0])),'Label':yhat_test_final_arr}

yhat_test_final_df=pd.DataFrame(data_final)

yhat_test_final_df.to_csv('yhat_test_final.csv', index=False)

yhat_test_final_df.to_csv('yhat_test_final.txt', index=False)


# Acquire first batch of test images.
dataiter2 = iter(test_loader)
images = dataiter2.next()

# Plot test images to ensure proper functionality.
imshow(torchvision.utils.make_grid(images))
# Out:
# <HDF5 dataset "train_dataset": shape (56000, 64, 64, 1), type "|u1">
# <HDF5 dataset "train_labels": shape (56000, 5), type "<i4">
# <HDF5 dataset "test_dataset": shape (14000, 64, 64, 1), type "|u1">
#
# Dataset Length: 14000
#
# Test Set Length: 14000
#
# Test Predictions (yhat_test_final):
# [[ 1 10 10  1 10]
#  [ 0  1  7  3 10]
#  [ 1  4  0  8  3]
#  ...
#  [ 1 10 10  1 10]
#  [ 4  1  9  7 10]
#  [ 5  8  3  0  9]]
#
# yhat_test_final shape: (14000, 5)
